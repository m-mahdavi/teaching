# %% [markdown]
# # Adversarial Search
# Consider the following adversarial search tree.
# ![adversarial_search_tree.png](data:image/png;base64,...)
#
#
# ## Tasks
# - Find the optimal action for the max player using the minimax and alpha-beta pruning algorithms.
# - Draw how the nodes will be traversed/pruned using the v, α, and β variables.
# - Discuss whether the order of visiting nodes can make any difference in the effectiveness and efficiency of the final solution or not.
# - Implement these search algorithms on the given search tree and check their solution in action.
