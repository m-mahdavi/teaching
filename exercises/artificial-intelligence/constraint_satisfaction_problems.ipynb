# %% [markdown]
# # Constraint Satisfaction Problems (CSPs)
# Consider the following CSP of coloring the map of Australia.
# - $ 𝑋=\{𝑊𝐴,𝑁𝑇,𝑄,𝑁𝑆𝑊,𝑉,𝑆𝐴,𝑇\} $
# - $ 𝐷_𝑖=\{𝑟𝑒𝑑,𝑔𝑟𝑒𝑒𝑛,𝑏𝑙𝑢𝑒\} $
# - $ 𝐶=\{𝑆𝐴≠𝑊𝐴,𝑆𝐴≠𝑁𝑇,𝑆𝐴≠𝑄,𝑆𝐴≠𝑁𝑆𝑊,𝑆𝐴≠𝑉,𝑊𝐴≠𝑁𝑇,𝑁𝑇≠𝑄,𝑄≠𝑁𝑆𝑊,𝑁𝑆𝑊≠𝑉\} $
#
# ![australia_map.png](data:image/png;base64,...)
#
#
# ## Tasks
# - Implement a backtracking search algorithm for this CSP using different heuristics and inference techniques.
# - Implement a local search algorithm for this CSP using different heuristics and inference techniques.
# - Compare the results of the above search approaches in terms of effectiveness and efficiency.
