# %% [markdown]
# # Multilayer Perceptron
# Load the `mnist` dataset. Split it into training and test sets. Train and test a multilayer perceptron model using scikit-learn. Check the documentation to identify the most important hyperparameters, attributes, and methods of the model. Use them in practice.

# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
import sklearn.metrics
import sklearn.linear_model
import sklearn.model_selection
import sklearn.neural_network
import plotly.express as px

# %% [markdown]
# ## Loading the Dataset

# %%
df = pd.read_csv("../../datasets/mnist.csv")
df = df.set_index("id")
df.head(3)
# Out:
#        class  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# id
# 31953      5       0       0       0       0       0       0       0       0
# 34452      8       0       0       0       0       0       0       0       0
# 60897      5       0       0       0       0       0       0       0       0
#
#        pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# id             ...
# 31953       0  ...         0         0         0         0         0
# 34452       0  ...         0         0         0         0         0
# 60897       0  ...         0         0         0         0         0
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# id
# 31953         0         0         0         0         0
# 34452         0         0         0         0         0
# 60897         0         0         0         0         0
#
# [3 rows x 785 columns]

# %% [markdown]
# ## Splitting the Data into Training and Test

# %%
x = df.drop(["class"], axis=1)
y = df["class"]
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y)

# %% [markdown]
# ## Model Selection and Hyperparameter Tuning

# %%
parameters_grid = {
    "solver": ["lbfgs", "sgd", "adam"],
    "batch_size": [10, 20, 50, 100, 200],
    "max_iter": [200, 400],
    "hidden_layer_sizes": [(50), (100), (50, 50), (50, 100), (100, 50), (100, 100)]
}
model_1 = sklearn.model_selection.GridSearchCV(sklearn.neural_network.MLPClassifier(), 
                                               parameters_grid, scoring="accuracy", cv=5, n_jobs=-1)
model_1.fit(x_train, y_train)
print("Accuracy of best Random Forest classfier = {:.2f}".format(model_1.best_score_))
print("Best found hyperparameters of Random Forest classfier = {}".format(model_1.best_params_))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %% [markdown]
# ## Testing the Trained Model

# %%
y_predicted = model_1.predict(x_test)
accuracy = sklearn.metrics.accuracy_score(y_test, y_predicted)
cm = sklearn.metrics.confusion_matrix(y_test, y_predicted)
precision, recall, f1, support = sklearn.metrics.precision_recall_fscore_support(y_test, y_predicted)

print("Accuracy =", accuracy)
print("Precision =", precision)
print("Recall =", recall)
print("F1-Score =", f1)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy = 0.935
# Precision = [0.99074074 0.94957983 0.8974359  0.96261682 0.98666667 0.90625
#  0.93617021 0.88333333 0.96296296 0.89156627]
# Recall = [0.94690265 0.97413793 0.96330275 0.92792793 0.88095238 0.93548387
#  0.94623656 0.9380531  0.90697674 0.90243902]
# F1-Score = [0.96832579 0.96170213 0.92920354 0.94495413 0.93081761 0.92063492
#  0.94117647 0.90987124 0.93413174 0.8969697 ]
# Confusion Matrix:
#  [[107   0   0   0   0   1   2   2   0   1]
#  [  0 113   2   1   0   0   0   0   0   0]
#  [  0   1 105   0   0   0   0   3   0   0]
#  [  0   0   2 103   0   2   0   1   2   1]
#  [  0   0   2   0  74   0   3   1   1   3]
#  [  0   0   2   1   0  87   1   1   0   1]
#  [  0   0   1   0   1   3  88   0   0   0]
#  [  1   2   2   0   0   0   0 106   0   2]
#  [  0   2   1   1   0   2   0   1  78   1]
#  [  0   1   0   1   0   1   0   5   0  74]]
